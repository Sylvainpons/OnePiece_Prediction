# %%
import pandas as pd
OnePiece_df = pd.read_csv('data_onePiece.csv')
OnePiece_df
# Out:
#        Chapter                                Title  \
# 0            4  Morgan, le Colonel à la main de fer
# 1            4  Morgan, le Colonel à la main de fer
# 2            4  Morgan, le Colonel à la main de fer
# 3            4  Morgan, le Colonel à la main de fer
# 4            4  Morgan, le Colonel à la main de fer
# ...        ...                                  ...
# 13976     1086           Le Conseil des Cinq Doyens
# 13977     1086           Le Conseil des Cinq Doyens
# 13978     1086           Le Conseil des Cinq Doyens
# 13979     1086           Le Conseil des Cinq Doyens
# 13980     1086           Le Conseil des Cinq Doyens
#
#                                                Image URL    Tome:  Chapitre:  \
# 0      https://static.wikia.nocookie.net/onepiece/ima...   Tome 1          4
# 1      https://static.wikia.nocookie.net/onepiece/ima...   Tome 1          4
# 2      https://static.wikia.nocookie.net/onepiece/ima...   Tome 1          4
# ...
